# %%
# Imports
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from pickle import load
import pandas as pd

# %%
# Load Data
X_train = np.load('X_train.npy')
X_test = np.load('X_test.npy')
y_train = np.load('y_train.npy')
y_test = np.load('y_test.npy')
index_train = np.load('index_train.npy', allow_pickle=True)
index_test = np.load('index_test.npy', allow_pickle=True)

# %%
# Define LSTM Model
def build_lstm_model(input_shape):
    """
    Builds and compiles an LSTM model for time series forecasting.

    Args:
        input_shape (tuple): The shape of the input data (timesteps, features).

    Returns:
        tf.keras.Model: Compiled LSTM model.
    """
    model = Sequential([
        LSTM(128, return_sequences=True, input_shape=input_shape, dropout=0.2, recurrent_dropout=0.2),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(1)  # Single output for regression
    ])
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return model

# %%
# Initialize LSTM Model
input_shape = (X_train.shape[1], X_train.shape[2])  # (timesteps, features)
lstm_model = build_lstm_model(input_shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train LSTM Model
def train_lstm_model(model, X_train, y_train, X_test, y_test, epochs=50, batch_size=32):
    """
    Trains the LSTM model on the given data.

    Args:
        model (tf.keras.Model): The LSTM model.
        X_train (numpy.ndarray): Training input data.
        y_train (numpy.ndarray): Training target data.
        X_test (numpy.ndarray): Validation input data.
        y_test (numpy.ndarray): Validation target data.
        epochs (int): Number of epochs for training.
        batch_size (int): Batch size for training.

    Returns:
        tf.keras.callbacks.History: Training history object.
    """

    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=epochs,
        batch_size=batch_size,
        verbose=1
    )
    return history

# %%
# Plot Training and Validation Losses
def plot_training_losses(history):
    """
    Plots the training and validation loss curves.

    Args:
        history (tf.keras.callbacks.History): History object returned by model.fit().
    """
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss', color='blue')
    plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Train the model
history = train_lstm_model(lstm_model, X_train, y_train, X_test, y_test, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.1872 - mae: 0.3565 - val_loss: 0.0394 - val_mae: 0.1815
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0634 - mae: 0.2004 - val_loss: 0.0157 - val_mae: 0.0883
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0400 - mae: 0.1657 - val_loss: 0.0168 - val_mae: 0.1111
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0391 - mae: 0.1620 - val_loss: 0.0222 - val_mae: 0.1312
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0355 - mae: 0.1513 - val_loss: 0.0129 - val_mae: 0.0940
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0327 - mae: 0.1439 - val_loss: 0.0113 - val_mae: 0.0826
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0320 - mae: 0.1440 - val_loss: 0.0119 - val_mae: 0.0904
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0329 - mae: 0.1489 - val_loss: 0.0124 - val_mae: 0.0933
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0318 - mae: 0.1419 - val_loss: 0.0127 - val_mae: 0.0943
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0266 - mae: 0.1327 - val_loss: 0.0112 - val_mae: 0.0846
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0323 - mae: 0.1461 - val_loss: 0.0112 - val_mae: 0.0772
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0303 - mae: 0.1433 - val_loss: 0.0109 - val_mae: 0.0820
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0281 - mae: 0.1330 - val_loss: 0.0110 - val_mae: 0.0790
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0297 - mae: 0.1344 - val_loss: 0.0110 - val_mae: 0.0829
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0276 - mae: 0.1348 - val_loss: 0.0120 - val_mae: 0.0737
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0242 - mae: 0.1254 - val_loss: 0.0109 - val_mae: 0.0773
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0267 - mae: 0.1302 - val_loss: 0.0161 - val_mae: 0.0880
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0238 - mae: 0.1214 - val_loss: 0.0112 - val_mae: 0.0796
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0242 - mae: 0.1271 - val_loss: 0.0114 - val_mae: 0.0733
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0261 - mae: 0.1266 - val_loss: 0.0118 - val_mae: 0.0726
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0227 - mae: 0.1190 - val_loss: 0.0117 - val_mae: 0.0714
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0208 - mae: 0.1158 - val_loss: 0.0110 - val_mae: 0.0701
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0227 - mae: 0.1234 - val_loss: 0.0131 - val_mae: 0.0752
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0266 - mae: 0.1275 - val_loss: 0.0098 - val_mae: 0.0717
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0232 - mae: 0.1165 - val_loss: 0.0122 - val_mae: 0.0706
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0237 - mae: 0.1240 - val_loss: 0.0126 - val_mae: 0.0726
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0187 - mae: 0.1101 - val_loss: 0.0100 - val_mae: 0.0686
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0201 - mae: 0.1124 - val_loss: 0.0179 - val_mae: 0.0964
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0203 - mae: 0.1132 - val_loss: 0.0132 - val_mae: 0.0786
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0213 - mae: 0.1157 - val_loss: 0.0099 - val_mae: 0.0664
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0187 - mae: 0.1046 - val_loss: 0.0149 - val_mae: 0.0871
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0204 - mae: 0.1143 - val_loss: 0.0112 - val_mae: 0.0693
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0211 - mae: 0.1140 - val_loss: 0.0084 - val_mae: 0.0671
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0176 - mae: 0.1071 - val_loss: 0.0176 - val_mae: 0.1000
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0186 - mae: 0.1102 - val_loss: 0.0082 - val_mae: 0.0695
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0207 - mae: 0.1142 - val_loss: 0.0239 - val_mae: 0.1246
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0220 - mae: 0.1152 - val_loss: 0.0103 - val_mae: 0.0703
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0176 - mae: 0.1079 - val_loss: 0.0117 - val_mae: 0.0735
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0177 - mae: 0.1064 - val_loss: 0.0112 - val_mae: 0.0728
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0168 - mae: 0.1036 - val_loss: 0.0136 - val_mae: 0.0864
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0184 - mae: 0.1099 - val_loss: 0.0118 - val_mae: 0.0771
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0219 - mae: 0.1146 - val_loss: 0.0130 - val_mae: 0.0821
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0212 - mae: 0.1090 - val_loss: 0.0184 - val_mae: 0.1070
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0173 - mae: 0.1049 - val_loss: 0.0111 - val_mae: 0.0756
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0202 - mae: 0.1131 - val_loss: 0.0181 - val_mae: 0.1018
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0206 - mae: 0.1110 - val_loss: 0.0105 - val_mae: 0.0725
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0164 - mae: 0.1022 - val_loss: 0.0170 - val_mae: 0.0993
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0170 - mae: 0.1031 - val_loss: 0.0124 - val_mae: 0.0809
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0181 - mae: 0.1027 - val_loss: 0.0118 - val_mae: 0.0788
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0139 - mae: 0.0924 - val_loss: 0.0221 - val_mae: 0.1220

# %%
# Plot Training and Validation Losses
plot_training_losses(history)

# %%
# Evaluate Model
def evaluate_model(y_true, y_pred, index_test):
    """
    Evaluates the model's predictions using MSE, MAPE, and RMSE.
    Matches the logic from plot_test_data for RMSE calculation.

    Args:
        y_true (numpy.ndarray): The true target values.
        y_pred (numpy.ndarray): The predicted target values.
        index_test (numpy.ndarray): The index for test samples.

    Returns:
        dict: A dictionary containing MSE, MAPE, and RMSE.
    """
    # Load scalers
    y_scaler = load(open('y_scaler.pkl', 'rb'))

    # Rescale predictions and true values
    rescaled_y_true = y_scaler.inverse_transform(y_true)
    rescaled_y_pred = y_scaler.inverse_transform(y_pred)

    # Create DataFrames for alignment
    predict_result = pd.DataFrame(rescaled_y_pred, columns=["predicted_mean"], index=index_test)
    real_price = pd.DataFrame(rescaled_y_true, columns=["real_mean"], index=index_test)

    # Extract final predictions and real values
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]

    # Calculate metrics
    mse = mean_squared_error(real, predicted)
    mape = mean_absolute_percentage_error(real, predicted)
    rmse = np.sqrt(mse)

    # Print results
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

    return {"MSE": mse, "MAPE": mape, "RMSE": rmse}

# %%
# Generate Predictions
y_pred = lstm_model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step

# %%
# Plot Test Results
def plot_test_data(y_true, y_pred, index_test):
    """
    Plots the test results (real vs. predicted prices).

    Args:
        y_true (numpy.ndarray): Real stock prices for test data.
        y_pred (numpy.ndarray): Predicted stock prices by the LSTM model.
        index_test (numpy.ndarray): Index for the test data.
    """
    y_scaler = load(open('y_scaler.pkl', 'rb'))
    rescaled_y_true = y_scaler.inverse_transform(y_true)
    rescaled_y_pred = y_scaler.inverse_transform(y_pred)

    plt.figure(figsize=(16, 8))
    plt.plot(index_test, rescaled_y_true, label="Real Prices", color="blue")
    plt.plot(index_test, rescaled_y_pred, label="Predicted Prices", color="red", linestyle='--')
    plt.xlabel("Date")
    plt.ylabel("Stock Price")
    plt.legend()
    plt.title("Real vs Predicted Stock Prices")
    plt.show()

# Plot Results
plot_test_data(y_test, y_pred, index_test)

# %%
# Evaluate Performance
metrics = evaluate_model(y_test, y_pred, index_test)
# Out:
# Mean Squared Error (MSE): 37.6372
# Mean Absolute Percentage Error (MAPE): 0.0398
# Root Mean Squared Error (RMSE): 6.1349
